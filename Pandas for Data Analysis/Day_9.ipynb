# %% [markdown]
# ### Reshaping and Pivoting Indexes

# %%
import pandas as pd

# %%
# Inzip the file first.
import zipfile as zip

with zip.ZipFile (r"C:\Users\seid\Downloads\reshaping-and-pivoting-indexes-pklvl.zip") as z:
    print(z.namelist())
# Out:
# ['tech_price.xlsx']

# %%
# Unzip and read the Excel file

import zipfile as zip
import pandas as pd

with zip.ZipFile(
    r"C:\Users\seid\Downloads\reshaping-and-pivoting-indexes-pklvl.zip"
) as z:
    
    with z.open("tech_price.xlsx") as f:
        df = pd.read_excel(
            f,
            header=[0, 1],
            index_col=[0, 1]
        )

# %%
df
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
#            Amazon   12   43  97    75   25   25  90    43
# 2023-01-02 Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
#            Amazon   41   86  13    19   41   36  50    26
# 2023-01-03 Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
#            Amazon   71   15  47    53   86   44  68    33
# 2023-01-04 Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
#            Amazon   64   97  64    56   48   57  45    50
# 2023-01-05 Apple    34   45  60    84   24   49  63    54
#            Google   69   92  14    63   21   85  80    87
# ...

# %%
df2 = df.stack()

# %%
df2.unstack()
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Amazon   12   43  97    75   25   25  90    43
#            Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
# 2023-01-02 Amazon   41   86  13    19   41   36  50    26
#            Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
# 2023-01-03 Amazon   71   15  47    53   86   44  68    33
#            Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
# 2023-01-04 Amazon   64   97  64    56   48   57  45    50
#            Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
# 2023-01-05 Amazon   63   75  27    43   91   63  95    30
#            Apple    34   45  60    84   24   49  63    54
# ...

# %%
df_world = pd.read_csv(r"C:\Users\seid\Downloads\creating-an-index-bleua.zip", encoding = "cp1252")

pd.set_option('display.max.rows', 1350)
pd.set_option('display.max.columns', 15)
df_world
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df_world.pivot(index = ['continent', 'sub_region'], columns = 'country', values = 'Unnamed: 4')
# Out:
# country                              Afghanistan      Albania      Algeria  \
# continent sub_region
# Africa    Eastern Africa                     NaN          NaN          NaN
#           Middle Africa                      NaN          NaN          NaN
#           Northern Africa                    NaN          NaN   9,500,000
#           Southern Africa                    NaN          NaN          NaN
#           Western Africa                     NaN          NaN          NaN
# Americas  Caribbean                          NaN          NaN          NaN
#           Central America                    NaN          NaN          NaN
#           Northern America                   NaN          NaN          NaN
#           South America                      NaN          NaN          NaN
# Asia      Central Asia                       NaN          NaN          NaN
#           Eastern Asia                       NaN          NaN          NaN
# ...

# %%
df_world.rename(columns = {"Unnamed: 4": "Population"}, inplace = True)

# %%
df_world.pivot(index = ['continent', 'sub_region'], columns = 'country', values = 'Population')
# Out:
# country                              Afghanistan      Albania      Algeria  \
# continent sub_region
# Africa    Eastern Africa                     NaN          NaN          NaN
#           Middle Africa                      NaN          NaN          NaN
#           Northern Africa                    NaN          NaN   9,500,000
#           Southern Africa                    NaN          NaN          NaN
#           Western Africa                     NaN          NaN          NaN
# Americas  Caribbean                          NaN          NaN          NaN
#           Central America                    NaN          NaN          NaN
#           Northern America                   NaN          NaN          NaN
#           South America                      NaN          NaN          NaN
# Asia      Central Asia                       NaN          NaN          NaN
#           Eastern Asia                       NaN          NaN          NaN
# ...
