# %% [markdown]
# ### Filtering using Date Functions

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\seid\Downloads\filtering-using-date-functions-iused.zip")
df
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 0         3/26/2006  Mostly Cloudy        rain         5.183333
# 1         3/27/2006  Mostly Cloudy        rain         3.722222
# 2         3/28/2006  Mostly Cloudy        rain         4.855556
# 3         3/29/2006          Foggy        rain         5.211111
# 4         3/30/2006       Overcast        rain         6.255556
# ...             ...            ...         ...              ...
# 2358     10/26/2016  Partly Cloudy        snow        -2.155556
# 2359     10/27/2016  Partly Cloudy        snow        -2.816667
# 2360     10/28/2016          Clear        snow        -2.827778
# 2361     10/29/2016  Partly Cloudy        snow        -3.750000
# 2362     10/30/2016  Mostly Cloudy        snow        -4.705556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     4.111111      0.91             5.5384
# 1                     2.566667      0.94             5.2003
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            2363 non-null   datetime64[us]
#  1   Summary                   2363 non-null   str
#  2   Precip Type               2363 non-null   str
#  3   Temperature (C)           2363 non-null   float64
#  4   Apparent Temperature (C)  2363 non-null   float64
#  5   Humidity                  2363 non-null   float64
#  6   Wind Speed (km/h)         2363 non-null   float64
#  7   Wind Bearing (degrees)    2363 non-null   int64
#  8   Visibility (km)           2363 non-null   float64
#  9   Loud Cover                2363 non-null   int64
#  10  Pressure (millibars)      2363 non-null   float64
#  11  Daily Summary             2363 non-null   str
# dtypes: datetime64[us](1), float64(6), int64(2), str(3)
# memory usage: 221.7 KB

# %%
df["Formatted Date"] = pd.to_datetime(df["Formatted Date"])

# %%
df
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 0         3/26/2006  Mostly Cloudy        rain         5.183333
# 1         3/27/2006  Mostly Cloudy        rain         3.722222
# 2         3/28/2006  Mostly Cloudy        rain         4.855556
# 3         3/29/2006          Foggy        rain         5.211111
# 4         3/30/2006       Overcast        rain         6.255556
# ...             ...            ...         ...              ...
# 2358     10/26/2016  Partly Cloudy        snow        -2.155556
# 2359     10/27/2016  Partly Cloudy        snow        -2.816667
# 2360     10/28/2016          Clear        snow        -2.827778
# 2361     10/29/2016  Partly Cloudy        snow        -3.750000
# 2362     10/30/2016  Mostly Cloudy        snow        -4.705556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     4.111111      0.91             5.5384
# 1                     2.566667      0.94             5.2003
# ...

# %%
df[df["Formatted Date"].dt.day== 6]
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 11       2006-04-06  Mostly Cloudy        rain        11.183333
# 41       2006-05-06  Partly Cloudy        rain        16.016667
# 72       2006-06-06  Mostly Cloudy        rain         7.338889
# 102      2006-07-06       Overcast        rain        11.038889
# 133      2006-08-06  Partly Cloudy        rain        12.755556
# ...             ...            ...         ...              ...
# 2216     2016-06-06          Foggy        snow        -1.038889
# 2246     2016-07-06          Foggy        snow        -2.805556
# 2277     2016-08-06  Mostly Cloudy        rain        10.027778
# 2308     2016-09-06          Foggy        snow        -4.866667
# 2338     2016-10-06       Overcast        snow        -3.733333
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 11                   11.183333      0.80            10.8192
# 41                   16.016667      0.48            11.2378
# ...

# %%
df[df["Formatted Date"].dt.month== 6]
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 67       2006-06-01       Overcast        rain         8.794444
# 68       2006-06-02       Overcast        rain         6.172222
# 69       2006-06-03       Overcast        rain         7.983333
# 70       2006-06-04       Overcast        rain         7.894444
# 71       2006-06-05       Overcast        rain         7.311111
# ...             ...            ...         ...              ...
# 2236     2016-06-26          Foggy        snow        -1.500000
# 2237     2016-06-27  Mostly Cloudy        snow        -4.250000
# 2238     2016-06-28          Foggy        snow        -0.994444
# 2239     2016-06-29          Foggy        snow        -1.594444
# 2240     2016-06-30          Foggy        snow        -2.150000
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 67                    6.816667      0.71            12.3648
# 68                    2.922222      0.76            17.0499
# ...

# %%
df[df["Formatted Date"].dt.date == pd.to_datetime("2006/6/3").date()]
# Out:
#    Formatted Date   Summary Precip Type  Temperature (C)  \
# 69     2006-06-03  Overcast        rain         7.983333
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 69                  6.811111      0.75             7.3416
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 69                     172            9.982           0               1010.39
#
#                    Daily Summary
# 69  Overcast throughout the day.

# %%
df[df["Formatted Date"].dt.date == pd.to_datetime("2006-06-03").date()]
# Out:
#    Formatted Date   Summary Precip Type  Temperature (C)  \
# 69     2006-06-03  Overcast        rain         7.983333
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 69                  6.811111      0.75             7.3416
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 69                     172            9.982           0               1010.39
#
#                    Daily Summary
# 69  Overcast throughout the day.

# %%
df[df["Formatted Date"].dt.day_name() == "Monday"]
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 1        2006-03-27  Mostly Cloudy        rain         3.722222
# 8        2006-04-03  Partly Cloudy        rain        10.116667
# 15       2006-04-10  Partly Cloudy        rain         9.355556
# 22       2006-04-17  Partly Cloudy        rain        10.822222
# 29       2006-04-24  Partly Cloudy        rain        15.388889
# ...             ...            ...         ...              ...
# 2328     2016-09-26  Mostly Cloudy        snow        -2.244444
# 2335     2016-10-03  Partly Cloudy        snow        -4.283333
# 2342     2016-10-10  Mostly Cloudy        snow        -3.655556
# 2349     2016-10-17  Mostly Cloudy        snow        -2.783333
# 2356     2016-10-24  Partly Cloudy        rain         0.255556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1                     2.566667      0.94             5.2003
# 8                    10.116667      0.79             6.6493
# ...
