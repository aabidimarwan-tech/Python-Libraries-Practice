# %%
import numpy as np
import pandas as pd

# %%
my_list = [10, 28, 7, 9]

x = np.array(my_list) 
print(x)
# Out:
# [10 28  7  9]

# %%
x
# Out:
# array([10, 28,  7,  9])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
# by default: pd.Series(data = my_list, index = ...)

y = pd.Series(my_list)
y
# Out:
# 0    10
# 1    28
# 2     7
# 3     9
# dtype: int64

# %%
type(y)
# Out:
# pandas.Series

# %%
index_values = ["best", "second best", "third best"]
my_list = [90, 65, 35]

one =pd.Series(index = index_values , data = my_list)
one
# Out:
# best           90
# second best    65
# third best     35
# dtype: int64

# %%
index_values2 = ["best", "second best", "forth best"]
my_list2 = [90, 65, 35]

two =pd.Series(index = index_values2 , data = my_list2)
two
# Out:
# best           90
# second best    65
# forth best     35
# dtype: int64

# %%
total = one + two
total
# Out:
# best           180.0
# forth best       NaN
# second best    130.0
# third best       NaN
# dtype: float64

# %%
pd.DataFrame({"Serie 1" : one, "Serie 2" : two})
# Out:
#              Serie 1  Serie 2
# best            90.0     90.0
# forth best       NaN     35.0
# second best     65.0     65.0
# third best      35.0      NaN

# %%
ice_cream = [["MCC", 1], ["Butterscotch", 2], ["Butter Pecan", 3]]
pd.DataFrame(ice_cream, index = ["Flavor 1", "Flavor 2", "Flavor 3"], columns = ["Flavor", "Scoop"])
# Out:
#                 Flavor  Scoop
# Flavor 1           MCC      1
# Flavor 2  Butterscotch      2
# Flavor 3  Butter Pecan      3
